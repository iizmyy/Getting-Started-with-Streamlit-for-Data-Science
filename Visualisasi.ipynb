# %% [markdown]
# <a href="https://colab.research.google.com/github/iizmyy/Getting-Started-with-Streamlit-for-Data-Science/blob/main/Visualisasi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# sumber data {https://en.wikipedia.org/wiki/Box_plot#Examples}
suhu = {'Suhu(F)':[57, 57, 57, 58, 63, 66, 66, 67, 67, 68, 69, 70, 70, 70, 70, 72, 73, 75, 75, 76, 76, 78, 79, 81],
        'Suhu(F)_with_Outlier':[52, 57, 57, 58, 63, 66, 66, 67, 67, 68, 69, 70, 70, 70, 70, 72, 73, 75, 75, 76, 76, 78, 79, 89]}
df = pd.DataFrame(data=suhu)
boxplot = df.boxplot(column=['Suhu(F)','Suhu(F)_with_Outlier'], fontsize=12, figsize=(5,7), rot=-20)

# %%
pip install palmerpenguins

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from palmerpenguins import load_penguins

penguins = load_penguins()
plt.figure(figsize=[9,7])
sns.set_theme(style="whitegrid")
ax = sns.boxplot(x='species', y='body_mass_g', data=penguins, hue='species', palette="bright", linewidth=2)
ax.set_title('Palmer Penguins')
ax.set_xlabel('species')
ax.set_ylabel('Body Mass')
# Out:
# Text(0, 0.5, 'Body Mass')
